# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit

# %%
#Carica dati
data=np.loadtxt("Uniforme.dat")
#Valori dell'ascissa
x=np.array([i+1 for i in range(100)])

#Grafico con errore
plt.errorbar(x, data[:,0],yerr=data[:,1],label="Montecarlo")
plt.plot(x,np.ones(100),label="Attesi")
#Parte estetica
plt.xlabel("Numero stime")
plt.ylabel(r"$\langle I \rangle $")
plt.title(f"Integrale MonteCarlo\nDistribuzione uniforme")
plt.legend()
plt.grid(True)

plt.show()

# %%
#Carica dati
data=np.loadtxt("Imp_Sampling.dat")
#Valori dell'ascissa
x=np.array([i+1 for i in range(100)])

#Grafico con errore
plt.errorbar(x, data[:,0],yerr=data[:,1],label="Montecarlo")
plt.plot(x,np.ones(100),label="Attesi")
#Parte estetica
plt.xlabel("Numero stime")
plt.ylabel(r"$\langle I \rangle $")
plt.title(f"Integrale MonteCarlo\nImportance Sampling")
plt.legend()
plt.grid(True)

plt.show()

# %%
#Carica dati
data=np.loadtxt("Uniforme.dat")
data1=np.loadtxt("Imp_Sampling.dat")
#Valori dell'ascissa
x=np.array([i+1 for i in range(100)])

#Grafico con errore
plt.errorbar(x, data[:,0],yerr=data[:,1],label="Distribuzione Uniforme")
plt.errorbar(x, data1[:,0],yerr=data1[:,1],label="Importance Sampling")
plt.plot(x,np.ones(100),label="Attesi")
#Parte estetica
plt.xlabel("Numero stime")
plt.ylabel(r"$\langle I \rangle $")
plt.title(f"Integrale MonteCarlo\nComparati")
plt.legend()
plt.grid(True)

plt.show()

# %%
#Carico dati da file e inizializzo le ascisse
data=np.loadtxt("RandomWalk.dat")
dim=np.shape(data)[0]
x=np.linspace(1,dim,dim)

#Faccio un fit dei dati
def my_func(x,k):
    return k*np.sqrt(x)
popt, pcov=curve_fit(my_func,x,data[:,0],sigma=data[:,2])

#Plotto i dati
plt.errorbar(x,data[:,0],yerr=data[:,2],label="Simulati")
plt.plot(x,my_func(x,popt),color="red",label="Attesi")

#Estetica
plt.title(f"Random Walk\nDiscreto")
plt.xlabel("N")
plt.ylabel(r"$\sqrt{\left\langle|r_N|^2\right\rangle_{RW}}$")
plt.legend()
plt.grid(True)

plt.show()

# %%
plt.errorbar(x,data[:,0]-my_func(x,popt),yerr=data[:,2],label="Simulati")
plt.plot(x,np.zeros(dim),label="Attesi")
plt.grid()
plt.legend()

plt.show()

# %%
#Faccio un fit dei dati
cpopt, pcov=curve_fit(my_func,x,data[:,1],sigma=data[:,3])

#Plotto i dati
plt.errorbar(x,data[:,1],yerr=data[:,3],label="Simulati")
plt.plot(x,my_func(x,cpopt),color="red",label="Attesi")

#Estetica
plt.title(f"Random Walk\nContinuo")
plt.xlabel("N")
plt.ylabel(r"$\sqrt{\left\langle|r_N|^2\right\rangle_{RW}}$")
plt.legend()
plt.grid(True)

plt.show()

# %%
plt.errorbar(x,data[:,1]-my_func(x,cpopt),yerr=data[:,3],label="Simulati")
plt.plot(x,np.zeros(dim),label="Attesi")
plt.grid()
plt.legend()

plt.show()
